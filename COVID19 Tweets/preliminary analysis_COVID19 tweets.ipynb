# %%
import pandas as pd

# %%
df=pd.read_csv("../input/covid19-tweets/covid19_tweets.csv")

# %%
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df["user_location"].value_counts()
# Out:
# India                   3117
# United States           1991
# New Delhi, India        1447
# Mumbai, India           1136
# Washington, DC          1082
#                         ...
# Rensselaer, NY             1
# Lumding, India             1
# Halton Region              1
# Southern Pines, NC         1
# Brno, Czech Republic       1
# Name: user_location, Length: 23555, dtype: int64

# %% [markdown]
# Percentage of null values missing in the dataframe.

# %%
df.isnull().sum()*100/len(df)
# Out:
# user_name            0.000000
# user_location       20.318291
# user_description     5.667306
# user_created         0.000000
# user_followers       0.000000
# user_friends         0.000000
# user_favourites      0.000000
# user_verified        0.000000
# date                 0.000000
# text                 0.000000
# hashtags            28.596012
# source               0.032520
# is_retweet           0.000000
# dtype: float64

# %%
df["hashtags"].value_counts()
# Out:
# ['COVID19']                                                                                                    31057
# ['Covid19']                                                                                                     4097
# ['covid19']                                                                                                     2554
# ['coronavirus', 'CoronaVirusUpdate', 'COVID19', 'CoronavirusPandemic']                                           481
# ['coronavirus']                                                                                                  440
#                                                                                                                ...
# ['AlanVoiceAIHackathon']                                                                                           1
# ['standup', 'comedy', 'covid19', 'socialdistancing']                                                               1
# ...

# %%
len(df)
# Out:
# 147601

# %%
df["user_verified"].value_counts()
# Out:
# False    128186
# True      19415
# Name: user_verified, dtype: int64

# %%
df["user_description"].value_counts()[:100]
# Out:
# Breaking News & Critical Information to SURVIVE the Coronavirus Outbreak / Civil Unrest                                                                           486
# COVID-19 (Coronavirus) Latest News & Statistics.\nWe post updates 24/7 as they come in, all stats are from official sources.\n#Coronavirus #COVID19               482
# Coronavirus Statistics, Information & News                                                                                                                        401
# Copies of real letters delivered to the President, Congress, Governors, and State Legislators. Send 'resist' as a Direct Message to @resistbot to write yours.    356
# One of India's largest media companies. Latest news from around the world. Retweets are not endorsements                                                          244
# ...

# %%
df["source"].value_counts()
