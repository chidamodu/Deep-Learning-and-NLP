# %%
import pandas as pd

# %%
df=pd.read_csv("../input/covid19-tweets/covid19_tweets.csv")

# %%
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df["user_location"].value_counts()
# Out:
# India                   3182
# United States           2114
# New Delhi, India        1486
# Washington, DC          1236
# Mumbai, India           1163
#                         ...
# Harda, India,indore        1
# Dg, IL                     1
# Houston, TX 🤘🏾             1
# Bissen, Luxembourg         1
# Leigh On Sea               1
# Name: user_location, Length: 24459, dtype: int64

# %%
len(df["user_location"].value_counts())
# Out:
# 24459

# %% [markdown]
# Percentage of null values missing in the dataframe.

# %%
df.isnull().sum()*100/len(df)
# Out:
# user_name            0.000000
# user_location       20.226820
# user_description     5.647288
# user_created         0.000000
# user_followers       0.000000
# user_friends         0.000000
# user_favourites      0.000000
# user_verified        0.000000
# date                 0.000000
# text                 0.000000
# hashtags            28.720640
# source               0.034171
# is_retweet           0.000000
# dtype: float64

# %%
df["hashtags"].value_counts()
# Out:
# ['COVID19']                                                               32632
# ['Covid19']                                                                4237
# ['covid19']                                                                2680
# ['coronavirus', 'CoronaVirusUpdate', 'COVID19', 'CoronavirusPandemic']      508
# ['coronavirus']                                                             458
#                                                                           ...
# ['PrimaryImmunodeficiency']                                                   1
# ['COVID19', 'Slovakia', 'EurydiceEU']                                         1
# ['NationalGirlfriendDay']                                                     1
# ['UK', 'COVID19', 'PoliceState']                                              1
# ['Delhi', 'COVID19', 'Delhiairport', 'coronatesting']                         1
# Name: hashtags, Length: 46350, dtype: int64

# %%
len(df)
# Out:
# 155101

# %%
df["user_verified"].value_counts()
# Out:
# False    134774
# True      20327
# Name: user_verified, dtype: int64

# %%
df["user_description"].value_counts()[:5]
# Out:
# Breaking News & Critical Information to SURVIVE the Coronavirus Outbreak / Civil Unrest                                                                           531
# COVID-19 (Coronavirus) Latest News & Statistics.\nWe post updates 24/7 as they come in, all stats are from official sources.\n#Coronavirus #COVID19               509
# Coronavirus Statistics, Information & News                                                                                                                        402
# Copies of real letters delivered to the President, Congress, Governors, and State Legislators. Send 'resist' as a Direct Message to @resistbot to write yours.    373
# One of India's largest media companies. Latest news from around the world. Retweets are not endorsements                                                          244
# Name: user_description, dtype: int64

# %%
df["source"].value_counts()
# Out:
# Twitter Web App              49756
# Twitter for Android          34333
# Twitter for iPhone           30423
# TweetDeck                     7549
# Hootsuite Inc.                6625
#                              ...
# CyberSecDN v.2                   1
# Imbibe Website Publishing        1
# Portal de CNMG                   1
# PublishToTwitter                 1
# Enthusiast97                     1
# Name: source, Length: 580, dtype: int64

# %% [markdown]
# First, let's try to group all the records by each country possible. Let's try using regex pattern.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df["user_location"].value_counts().plot.bar()

# %%
df.groupby("user_location").size().plot.bar()

# %%
for i in df["user_location"]:
    print(type(i))
#     if str(i).startswith("√úT:"):
#         print("yes")
#         print(i)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ...

# %% [markdown]
# Let's use the outputs from pd.to_numeric and boolean indexing to find the numerical values out of the column: user_location. But these values are not the ones we are looking for and that means they are represented as string values.

# %%
df[pd.to_numeric(df.user_location, errors='coerce').notnull()]
# Out:
#                                                user_name user_location  \
# 2807                                      Richard Dalton           404
# 2828                                  Birthday Blessings         65775
# 4478                       🇮🇪Huge, If True...🇮🇪 #WYS1WYG          1953
# 6535                                   Nashipae Lempaa 🌍          +254
# 11617                                            🦋EWest🦋         97501
# 15777                                             caffey         10101
# 17345                                direct democracy uk          1984
# 19607                                     Jacinda Fenske         32114
# 20352                                               JASB           +84
# 20884                                               JASB           +84
# 22866                                     David R Strong         78757
# 24127                                    the murderHobos         49504
# ...

# %%
import re
pattern=re.compile('^√úT:')

## THIS WAY YOU CAN CHECK FOR MULTIPLE STRINGS
## LIKE
## regex=re.compile('^hello|^john|^world')

for i in df["user_location"]:
    if re.match(pattern, str(i)):
        print("Yes")

# %%
df[df["user_location"]=="√úT: 37.322821,-121.809369"]
# Out:
# Empty DataFrame
# Columns: [user_name, user_location, user_description, user_created, user_followers, user_friends, user_favourites, user_verified, date, text, hashtags, source, is_retweet]
# Index: []

# %%
df[df.index.isin([16893, 16894])]
# Out:
#                       user_name     user_location  \
# 16893            Andy Bitchsear               NaN
# 16894  Kathryn Guylay, MBA, PhD  Sun Valley Idaho
#
#                                         user_description         user_created  \
# 16893  Corrupt Kentucky Governor and all around tyran...  2020-07-19 20:54:16
# 16894  Peak Performance Coach | https://t.co/KxVADa7v...  2015-01-23 22:44:47
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 16893               3             7               83          False
# 16894            9906          9377             7078          False
#
#                       date                                               text  \
# 16893  2020-07-24 23:59:23  @JohnCranley @Willie700WLW @MikeDeWine  Why is...
# 16894  2020-07-24 23:59:21  Practice safe, good habits – your mind and bod...
#
#       hashtags              source  is_retweet
# 16893      NaN  Twitter for iPhone       False
# ...

# %%
df.loc[df["user_name"]=="Charlie Isaacs", "user_location"]
# Out:
# 16891    ÜT: 37.322821,-121.809369
# Name: user_location, dtype: object

# %%
import re
from collections import defaultdict
pattern=re.compile('ÜT:')
d=defaultdict(list)

## THIS WAY YOU CAN CHECK FOR MULTIPLE STRINGS
## LIKE
## regex=re.compile('^hello|^john|^world')

for i in df["user_location"]:
    if re.match(pattern, str(i)):
        d[i].append(i)
        
#         d[i].append(df.index.get_loc)
        
#         d[df[df["user_location"]==i].index.values]=
#[df["user_location"]==i].index
# Out:
# Int64Index([979, 120674], dtype='int64')
# Int64Index([1968, 93175, 132796], dtype='int64')
# Int64Index([2203, 17536, 93027, 94299, 95387], dtype='int64')
# Int64Index([  2295,   3156,   4485,   4606,   5287,   5857,   8590,  16036,
#              17706,  17933,  19901,  20615,  21478,  30812,  30884,  30912,
#              31845,  33103,  67855,  67887,  69176,  70368,  73468,  76783,
#              79627,  81766,  86410,  91409,  94721,  95282, 106008, 106519,
#             111817, 112037, 118332, 119354, 120486, 120783, 122430, 124784,
#             127607, 132853, 136368, 137178, 137476, 138078, 138422, 138952,
#             140054],
#            dtype='int64')
# Int64Index([2660, 2731], dtype='int64')
# Int64Index([2660, 2731], dtype='int64')
# Int64Index([2733], dtype='int64')
# Int64Index([  2295,   3156,   4485,   4606,   5287,   5857,   8590,  16036,
#              17706,  17933,  19901,  20615,  21478,  30812,  30884,  30912,
# ...

# %%
d
# Out:
# defaultdict(list,
#             {'ÜT: 52.5127, 13.3811': [<bound method RangeIndex.get_loc of RangeIndex(start=0, stop=155101, step=1)>,
#               <bound method RangeIndex.get_loc of RangeIndex(start=0, stop=155101, step=1)>],
#              'ÜT: 51.551339,0.013024': [<bound method RangeIndex.get_loc of RangeIndex(start=0, stop=155101, step=1)>,
#               <bound method RangeIndex.get_loc of RangeIndex(start=0, stop=155101, step=1)>,
#               <bound method RangeIndex.get_loc of RangeIndex(start=0, stop=155101, step=1)>],
#              'ÜT: -26.532499,28.376949': [<bound method RangeIndex.get_loc of RangeIndex(start=0, stop=155101, step=1)>,
#               <bound method RangeIndex.get_loc of RangeIndex(start=0, stop=155101, step=1)>,
#               <bound method RangeIndex.get_loc of RangeIndex(start=0, stop=155101, step=1)>,
#               <bound method RangeIndex.get_loc of RangeIndex(start=0, stop=155101, step=1)>,
# ...

# %%
for i in df["user_location"]:
    if str(i).startswith('ÜT:'):
        d[i].append(df[df["user_location"]==i].index.values)

# %%
# import re
# from collections import defaultdict
# pattern=re.compile('ÜT:')
# d=defaultdict(list)

df.index[df["user_location"]=='ÜT:']
# Out:
# Int64Index([], dtype='int64')

# %%
# df.index[df.user_location.str.contains('^ÜT:')]

# df.iloc[df[s].index].index

# idx = df.index[df.Channel.isin(['A', 'B'])]

for i in df["user_location"]:
    
    df.index.get_loc(df.index[df.user_location.str.contains('^ÜT:', na=False)][0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-554de1509be4> in <module>
#       6
#       7 for i in df["user_location"]:
# ----> 8     df.index.get_loc(df.index[i.contains('^ÜT:', na=False)][0])
#
# AttributeError: 'str' object has no attribute 'contains'

# %%
#This is exactly what I wanted
df_userlocation=df[df['user_location'].str.contains('^ÜT:') == True].user_location

# %%
df_userlocation.head()
# Out:
# 979         ÜT: 52.5127, 13.3811
# 1968      ÜT: 51.551339,0.013024
# 2203    ÜT: -26.532499,28.376949
# 2295     ÜT: 3.099457,101.681025
# 2660     ÜT: 51.534976,-0.122796
# Name: user_location, dtype: object

# %%
df_userlocation=df_userlocation.reset_index()

# %%
df_userlocation.head()
# Out:
#    index             user_location
# 0    979      ÜT: 52.5127, 13.3811
# 1   1968    ÜT: 51.551339,0.013024
# 2   2203  ÜT: -26.532499,28.376949
# 3   2295   ÜT: 3.099457,101.681025
# 4   2660   ÜT: 51.534976,-0.122796

# %%
len(df_userlocation)
# Out:
# 299

# %%
df_userlocation.index.values
# Out:
# array([   979,   1968,   2203,   2295,   2660,   2731,   2733,   3156,
#          4485,   4606,   4689,   5287,   5857,   7094,   7139,   7193,
#          8590,   8910,   9514,  11031,  11189,  11589,  11690,  12824,
#         14295,  14606,  15665,  15696,  15931,  16036,  16187,  16416,
#         16482,  16699,  16891,  17129,  17536,  17706,  17864,  17933,
#         18019,  18363,  19032,  19066,  19067,  19070,  19071,  19901,
#         20615,  21478,  21622,  22505,  26481,  26570,  27789,  28380,
#         28876,  28885,  28967,  29847,  30812,  30860,  30884,  30912,
#         31003,  31285,  31503,  31653,  31845,  33103,  33185,  34581,
#         35962,  37446,  38886,  39700,  40954,  41656,  41765,  42682,
#         43469,  43793,  44690,  44732,  45599,  45932,  46216,  46394,
#         46775,  48514,  49027,  49395,  50394,  51278,  52163,  52496,
#         52648,  52994,  53443,  55423,  55756,  56721,  56884,  58611,
# ...

# %%
from geopy.geocoders import Nominatim
# create the locator
geolocator = Nominatim(user_agent="myGeocoder")

# getting the location address
location = geolocator.reverse("52.5127, 13.3811")
print(location)
# Out:
# Schlacht um Berlin, Gertrud-Kolmar-Straße, Mitte, Berlin, 10117, Deutschland

# %%
location2 = geolocator.reverse("51.551339,0.013024")

# %%
location2
# Out:
# Location(52, Heyworth Road, London Borough of Newham, London, Greater London, England, E15, United Kingdom, (51.5513381, 0.01284932824030964, 0.0))

# %%
location3=geolocator.reverse("-26.532499,28.376949")
str(location3)
# Out:
# 'Lesedi Ward 8, Lesedi Local Municipality, Sedibeng District Municipality, Gauteng, 1441, South Africa'

# %%
s="ÜT: 52.5127, 13.3811"
s.lstrip().rstrip()[4:]
# Out:
# '52.5127, 13.3811'

# %%
for i in df_userlocation["user_location"]:
    location = geolocator.reverse(i.lstrip().rstrip()[4:])
    print(location)
# Out:
# Schlacht um Berlin, Gertrud-Kolmar-Straße, Mitte, Berlin, 10117, Deutschland
# 52, Heyworth Road, London Borough of Newham, London, Greater London, England, E15, United Kingdom
# Lesedi Ward 8, Lesedi Local Municipality, Sedibeng District Municipality, Gauteng, 1441, South Africa
# Tadika Sempurna, Jalan Desa Permai, Taman Desa, Kuala Lumpur, 58100, Malaysia
# Chapel Down, Goods Way, Pentonville, King's Cross, London Borough of Islington, London, Greater London, England, N1C 4UR, United Kingdom
# Chapel Down, Goods Way, Pentonville, King's Cross, London Borough of Islington, London, Greater London, England, N1C 4UR, United Kingdom
# 159, Swan Street, Cremorne, City of Yarra, Victoria, 3121, Australia
# Tadika Sempurna, Jalan Desa Permai, Taman Desa, Kuala Lumpur, 58100, Malaysia
# Tadika Sempurna, Jalan Desa Permai, Taman Desa, Kuala Lumpur, 58100, Malaysia
# Tadika Sempurna, Jalan Desa Permai, Taman Desa, Kuala Lumpur, 58100, Malaysia
# ...

# %%
from geopy.geocoders import Nominatim
def lat_long_conversion(df, col1):
    df["address"]=""#let's add a new column to the same dataframe in order to add the results at appropriate indexes
    geolocator = Nominatim(user_agent="myGeocoder")
    for i in range(len(df[col1])):
        location = geolocator.reverse(df[col1][i].lstrip().rstrip()[4:])
        df.loc[i, "address"]=str(location)#without str in the statement here it issued an error saying cannot assign a multiindex values.
        #that's because values are separated by commas in an address
    return df

# %%
df_userlocation_altered=lat_long_conversion(df_userlocation, "user_location")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/geopy/geocoders/nominatim.py in reverse(self, query, exactly_one, timeout, language, addressdetails, zoom)
#     339         try:
# --> 340             lat, lon = self._coerce_point_to_string(query).split(',')
#     341         except ValueError:
#
# /opt/conda/lib/python3.7/site-packages/geopy/geocoders/base.py in _coerce_point_to_string(self, point, output_format)
#     294         if not isinstance(point, Point):
# --> 295             point = Point(point)
#     296
#
# /opt/conda/lib/python3.7/site-packages/geopy/point.py in __new__(cls, latitude, longitude, altitude)
#     164             elif isinstance(arg, str):
# --> 165                 return cls.from_string(arg)
#     166             else:
#
# /opt/conda/lib/python3.7/site-packages/geopy/point.py in from_string(cls, string)
# ...

# %%
df_userlocation.head()
# Out:
#    index             user_location  \
# 0    979      ÜT: 52.5127, 13.3811
# 1   1968    ÜT: 51.551339,0.013024
# 2   2203  ÜT: -26.532499,28.376949
# 3   2295   ÜT: 3.099457,101.681025
# 4   2660   ÜT: 51.534976,-0.122796
#
#                                              address
# 0  Schlacht um Berlin, Gertrud-Kolmar-Straße, Mit...
# 1  52, Heyworth Road, London Borough of Newham, L...
# 2  Lesedi Ward 8, Lesedi Local Municipality, Sedi...
# 3  Tadika Sempurna, Jalan Desa Permai, Taman Desa...
# 4  Chapel Down, Goods Way, Pentonville, King's Cr...

# %%
df_userlocation["index"]
# Out:
# 0         979
# 1        1968
# 2        2203
# 3        2295
# 4        2660
#         ...
# 294    152832
# 295    153246
# 296    153877
# 297    154180
# 298    154859
# Name: index, Length: 299, dtype: int64

# %%
for i in df_userlocation["user_location"]:
    print(i.lstrip().rstrip()[4:])
    
Observation:
Looks like we have some text in the column: "wa Tatakho"
Also value missing in: 33.87572,- (getting a value error for the missing value)
# Out:
# 52.5127, 13.3811
# 51.551339,0.013024
# -26.532499,28.376949
# 3.099457,101.681025
# 51.534976,-0.122796
# 51.534976,-0.122796
# -37.825664,144.996689
# 3.099457,101.681025
# 3.099457,101.681025
# 3.099457,101.681025
# 40.98595,-83.51754
# 3.099457,101.681025
# 3.099457,101.681025
# -26.712692,27.104824
# 18.547958,73.900569
# 53.526764,10.151374
# 3.099457,101.681025
# 30.1212241,31.320697
# 38.549431,-121.766323
# 6.504795,3.360384
# 33.857102,-118.199134
# 38.549431,-121.766323
# 34.018689,-118.483186
# 33.928552,-117.897795
# 33.679892,-117.79814
# 51.15887,-114.03066
# 34.188976,-118.613497
# 35.221715,-84.858944
# 29.64055,-82.396163
# 3.099457,101.681025
# 36.137439,-86.699082
# -6.1369253,106.6615827
# 34.018689,-118.483186
# 32.516629,-90.037161
# 37.322821,-121.809369
# 40.069263,-75.34257
# -26.532499,28.376949
# 3.099457,101.681025
# -26.712692,27.104824
# 3.099457,101.681025
# -26.712692,27.104824
# 51.474762,-0.137189
# 51.44724,-0.149176
# 18.547958,73.900569
# ...

# %%
Looks like Latitude and Longitude with values 0.0,0.0 should not be an issue

geolocator.reverse("0.0,0.0")
# Out:
# Location(Soul Buoy, (0.0, 0.0, 0.0))

# %%
Getting a ValueError: Must be a coordinate pair or Point
geolocator.reverse("33.87572,-")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/geopy/geocoders/nominatim.py in reverse(self, query, exactly_one, timeout, language, addressdetails, zoom)
#     339         try:
# --> 340             lat, lon = self._coerce_point_to_string(query).split(',')
#     341         except ValueError:
#
# /opt/conda/lib/python3.7/site-packages/geopy/geocoders/base.py in _coerce_point_to_string(self, point, output_format)
#     294         if not isinstance(point, Point):
# --> 295             point = Point(point)
#     296
#
# /opt/conda/lib/python3.7/site-packages/geopy/point.py in __new__(cls, latitude, longitude, altitude)
#     164             elif isinstance(arg, str):
# --> 165                 return cls.from_string(arg)
#     166             else:
#
# /opt/conda/lib/python3.7/site-packages/geopy/point.py in from_string(cls, string)
# ...

# %%
df_userlocation.drop("address", axis=1, inplace=True)

# %%
df_userlocation.head()
# Out:
#    index             user_location
# 0    979      ÜT: 52.5127, 13.3811
# 1   1968    ÜT: 51.551339,0.013024
# 2   2203  ÜT: -26.532499,28.376949
# 3   2295   ÜT: 3.099457,101.681025
# 4   2660   ÜT: 51.534976,-0.122796

# %%
df_userlocation[df_userlocation["user_location"].str.contains("wa Tatakho")]
# Out:
#       index    user_location
# 233  126252  ÜT:kwa Tatakho

# %%
#Let's remove the text from the column and also the latitude and longitude with a missing value from the column
#but this did not work

delete_row = df_userlocation[df_userlocation["user_location"]=="ÜT:kwa Tatakho"].index
df_userlocation.drop(delete_row, axis=0, inplace=True)

# %%
df_userlocation[df_userlocation["user_location"].str.contains("wa Tatakho")]
# Out:
#       index    user_location
# 233  126252  ÜT:kwa Tatakho

# %%
#removed index=126252 from the dataframe
df_userlocation.drop(233, inplace=True)

# %%
len(df_userlocation)
# Out:
# 298

# %%
df_userlocation[df_userlocation["user_location"].str.contains("wa Tatakho")]
# Out:
# Empty DataFrame
# Columns: [index, user_location]
# Index: []

# %%
df_userlocation[df_userlocation["user_location"].str.contains("33.87572,-")]
# Out:
#       index   user_location
# 264  137030  ÜT: 33.87572,-

# %%
#removed index=137030 from the dataframe
df_userlocation.drop(264, inplace=True)

# %%
len(df_userlocation)
# Out:
# 297

# %%
df_userlocation[df_userlocation["user_location"].str.contains("33.87572,-")]
# Out:
# Empty DataFrame
# Columns: [index, user_location]
# Index: []

# %%
from geopy.geocoders import Nominatim

def lat_long_conversion(df, col1):
    df["address"]=""#let's add a new column to the same dataframe in order to add the results at appropriate indexes
    geolocator = Nominatim(user_agent="myGeocoder")
    for i in range(len(df[col1])):
        try:
            location = geolocator.reverse(df[col1][i].lstrip().rstrip()[4:])
            df.loc[i, "address"]=str(location)#without str in the statement here it issued an error saying cannot assign a multiindex values.
        #that's because values are separated by commas in an address
        except:
            print("something's wrong with the coordinates {}".format(df[col1][i].lstrip().rstrip()[4:]))
    return df.head()

# %%
#It worked, yay!

lat_long_conversion(df_userlocation, "user_location")
# Out:
# something's wrong with the coordinates 19.,-155.93493
# something's wrong with the coordinates wa Tatakho
# something's wrong with the coordinates 33.87572,-
#    index             user_location  \
# 0    979      ÜT: 52.5127, 13.3811
# 1   1968    ÜT: 51.551339,0.013024
# 2   2203  ÜT: -26.532499,28.376949
# 3   2295   ÜT: 3.099457,101.681025
# 4   2660   ÜT: 51.534976,-0.122796
#
#                                              address
# 0  Schlacht um Berlin, Gertrud-Kolmar-Straße, Mit...
# 1  52, Heyworth Road, London Borough of Newham, L...
# 2  Lesedi Ward 8, Lesedi Local Municipality, Sedi...
# 3  Tadika Sempurna, Jalan Desa Permai, Taman Desa...
# 4  Chapel Down, Goods Way, Pentonville, King's Cr...

# %%
df_userlocation
# Out:
#       index              user_location  \
# 0       979       ÜT: 52.5127, 13.3811
# 1      1968     ÜT: 51.551339,0.013024
# 2      2203   ÜT: -26.532499,28.376949
# 3      2295    ÜT: 3.099457,101.681025
# 4      2660    ÜT: 51.534976,-0.122796
# ..      ...                        ...
# 294  152832  ÜT: 37.802874,-122.441077
# 295  153246   ÜT: 38.790393,-77.323839
# 296  153877  ÜT: 43.6508659,-79.380442
# 297  154180    ÜT: 41.268997,-96.12098
# 298  154859  ÜT: 47.225767,-122.471767
#
#                                                address
# 0    Schlacht um Berlin, Gertrud-Kolmar-Straße, Mit...
# 1    52, Heyworth Road, London Borough of Newham, L...
# 2    Lesedi Ward 8, Lesedi Local Municipality, Sedi...
# 3    Tadika Sempurna, Jalan Desa Permai, Taman Desa...
# 4    Chapel Down, Goods Way, Pentonville, King's Cr...
# ..                                                 ...
# 294  219, Avila Street, Marina District, San Franci...
# ...

# %%
#saving this file to /kaggle/working/ in the output directory. saving here will save the file outside the current session so
#can use it tomorrow. Proud of you Rockstar!

df_userlocation.to_csv("/kaggle/working/address_extracted.csv")

# %%
df2=pd.read_csv("./address_extracted.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0  index             user_location  \
# 0           0    979      ÜT: 52.5127, 13.3811
# 1           1   1968    ÜT: 51.551339,0.013024
# 2           2   2203  ÜT: -26.532499,28.376949
# 3           3   2295   ÜT: 3.099457,101.681025
# 4           4   2660   ÜT: 51.534976,-0.122796
#
#                                              address
# 0  Schlacht um Berlin, Gertrud-Kolmar-Straße, Mit...
# 1  52, Heyworth Road, London Borough of Newham, L...
# 2  Lesedi Ward 8, Lesedi Local Municipality, Sedi...
# 3  Tadika Sempurna, Jalan Desa Permai, Taman Desa...
# 4  Chapel Down, Goods Way, Pentonville, King's Cr...
