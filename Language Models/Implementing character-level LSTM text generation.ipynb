# %%
import keras
import numpy as np
path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 1us/step
# Corpus length: 600893

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []

# Vectorizing sequences of characters
# You’ll extract sequences of 60 characters.
# You’ll sample a new sequence every three characters.
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])

print('Number of sequences:', len(sentences))

# Holds the targets (the follow-up characters)
# List of unique characters in the corpus
# Dictionary that maps unique characters to their index in the list “chars”
# Holds the extracted sequences

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))

char_indices = dict((char, chars.index(char)) for char in chars)
print('Vectorization...')

x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# Function to sample the next character given the model’s prediction

def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys
for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)

    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen] 
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        
    for i in range(400):
        sampled = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(generated_text):
            sampled[0, t, char_indices[char]] = 1.
        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = chars[next_index]
        generated_text += next_char
        generated_text = generated_text[1:]
        sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.3149
# --- Generating with seed: "ervation is essential. the repulsive aspect of psychological"
# ------ temperature: 0.2
# ervation is essential. the repulsive aspect of psychological------ temperature: 0.5
# ervation is essential. the repulsive aspect of psychological------ temperature: 1.0
# ervation is essential. the repulsive aspect of psychological------ temperature: 1.2
# ervation is essential. the repulsive aspect of psychological from ether: in must seems occasionocly formest--"bund, as formers to menty be false:ms sufferables that hers.
# how heaut cravelon--that bitled gro, i froblical will as a equived his heapten
# depend nestered and
# doneal toletherneable hand, to gom, that is to spongly
# on one the self. but without hehow erver so times my he very know this certain, then: rate us du
# nought eventanawly new, awtwoy dionnesepoch 2
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.3111
# --- Generating with seed: "inding, and that prior to that
# event it seemed only the more"
# ------ temperature: 0.2
# inding, and that prior to that
# event it seemed only the more------ temperature: 0.5
# inding, and that prior to that
# event it seemed only the more------ temperature: 1.0
# inding, and that prior to that
# event it seemed only the more------ temperature: 1.2
# inding, and that prior to that
# event it seemed only the more clearlious other we non like give, perhaps a
# moralows, advance
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# as of such an european all fully, socrity (namethly, longed non unit. the neca summertror work run xirness and gothaim of the natifis want.fer-malks at full-moraln
# sowned for rare the
# way than thee-lifferoricily
# presencially as
# interpretiemts for
# remate always fancioniesial a"pschizeclonisr
# fig, we laques and place itself, be galiby tepoch 3
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3075
# --- Generating with seed: "is their favourite disguise. and as a matter of
# fact, the fa"
# ------ temperature: 0.2
# is their favourite disguise. and as a matter of
# fact, the fa------ temperature: 0.5
# is their favourite disguise. and as a matter of
# fact, the fa------ temperature: 1.0
# is their favourite disguise. and as a matter of
# fact, the fa------ temperature: 1.2
# is their favourite disguise. and as a matter of
# fact, the fal
# stally books min not strongers with
# "natur.
# -inderedgerss and
# kind of
# thoe, however who
# races the josing variable. to moral powerfulness as tcetuapars" critics" must histogerism to restong tatter, type.
#
#
# 18 to perminty
# to a
# bhing, the homang-melok-ally
# cannot
# infirration ridime dub.--what has relpert of indigbated, the he write
# over who in the gre'ay, is more accordonous forcote--the very intirepoch 4
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3048
# --- Generating with seed: "
# 4
#
# from this morbid solitude, from the deserts of such tria"
# ------ temperature: 0.2
#
# 4
#
# from this morbid solitude, from the deserts of such tria------ temperature: 0.5
#
# 4
#
# from this morbid solitude, from the deserts of such tria------ temperature: 1.0
#
# 4
#
# from this morbid solitude, from the deserts of such tria------ temperature: 1.2
#
# 4
#
# from this morbid solitude, from the deserts of such triaks
# hime; hoo physics of circifally
# leadt another! in the
# will--indormour baomile have concerned, it ouh: a sibenism, tedice the inducing relar
# dene such, whether he is stoolding, time
# hreaves. insures, not have
# hik
# even claitever,, it he to
# did not themselves form anding against memorience--the world hartime in their
# science in the world, he he discore abpeguane, "favorable will duty eavyone:
# eep epoch 5
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.3031
# --- Generating with seed: "that acts so
# effectively and irresistibly upon the beholders"
# ------ temperature: 0.2
# that acts so
# effectively and irresistibly upon the beholders------ temperature: 0.5
# that acts so
# effectively and irresistibly upon the beholders------ temperature: 1.0
# that acts so
# effectively and irresistibly upon the beholders------ temperature: 1.2
# that acts so
# effectively and irresistibly upon the beholdersations of life; but relent bevorctoricy with sofficul with explundence knowing to many
# who than
# so that to allisaleyion, thuse all
# over) in their conducat-purissofied in it poilsh
# witherlward as
# theurd sense-pusination, orrumed appace of
# christianists a powe fracts wine ruddly.ly inclinaly that place kangerness, my moral, under profouning farth" causeur
# that scho
# rong li. )ies without shord, more
# epoch 6
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2987
# --- Generating with seed: "et were there
# steps affording approach to this goal, how utt"
# ------ temperature: 0.2
# et were there
# steps affording approach to this goal, how utt------ temperature: 0.5
# et were there
# steps affording approach to this goal, how utt------ temperature: 1.0
# et were there
# steps affording approach to this goal, how utt------ temperature: 1.2
# et were there
# steps affording approach to this goal, how utter and armomily stipiness.--for here the
# weal-withouph th
# shumtent, both ragement
# of vow, as na gowary.
#
# 224. without
# benerlis to age hence so knowmerper forehoigty. from the pwilance.s, as in
# trusd." whenceunden       in all the he look of
# advance different as the idea of of instinctss, in hypological csken right no very demands
# hengent and could .
#
# 238. start last,
# every mank:
# !--accriy to old sepoch 7
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2982
# --- Generating with seed: "rit, which instinctively aims at
# appearance and superficiali"
# ------ temperature: 0.2
# rit, which instinctively aims at
# appearance and superficiali------ temperature: 0.5
# rit, which instinctively aims at
# appearance and superficiali------ temperature: 1.0
# rit, which instinctively aims at
# appearance and superficiali------ temperature: 1.2
# rit, which instinctively aims at
# appearance and superficialing for name
# about
# our greans belitatreive, honed man parthing about all seliemy reader others haveed in that is, and he asmed pour to be lighty and plato, and inciress its wordly
# vurisbarions thereby a mind man) finds essenrious" thus, as became thrinted vanity of him impossiar very deful
# digreer are europeeby, impequation.
#
#
# luubly mo(sin fusch befored'ness, suetked. this dediman i bitn old decodepoch 8
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2936
# --- Generating with seed: "chondria,
# from which those singular, religiously agitated pe"
# ------ temperature: 0.2
# chondria,
# from which those singular, religiously agitated pe------ temperature: 0.5
# chondria,
# from which those singular, religiously agitated pe------ temperature: 1.0
# chondria,
# from which those singular, religiously agitated pe------ temperature: 1.2
# chondria,
# from which those singular, religiously agitated permaced too lenou,gacally afford.
#
# rulom, even
# virtue? we a passionsed and langus,
# the
# schopenhauered. we looks has
# other only ir-agaive
# bastodible, hian, e-ofies of extrainabal inferedent
# sphing,
# what you in
# the himself supposintius. the fublesings of admor above indeedn the states: he may constends onver, therefore
# choo-gouder our preferts explainty in-meases, sass," mamenes, eleman
# a will trreasepoch 9
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2914
# --- Generating with seed: "s made nowadays to replace commanders
# by the summing togethe"
# ------ temperature: 0.2
# s made nowadays to replace commanders
# by the summing togethe------ temperature: 0.5
# s made nowadays to replace commanders
# by the summing togethe------ temperature: 1.0
# s made nowadays to replace commanders
# by the summing togethe------ temperature: 1.2
# s made nowadays to replace commanders
# by the summing togethery
# prudend innesterle! ganking
# or "opposing,
# dungnefut, would rule in the imagines
# stress
# deeping canous, prood bring poit his represes, perhaps to
# religiory test
# platorwibll--istomicians. although.
#
# to it also wishes and thing of
# meded, rank" in
# ths historians"; a srou.egpcean one's dwjexused; it is per"used
# to ulless, am sone an influent "old english awaken."--it is a maits;--we are on they u. tepoch 10
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2896
# --- Generating with seed: " too often justified
# in germany one has only to live for a w"
# ------ temperature: 0.2
#  too often justified
# in germany one has only to live for a w------ temperature: 0.5
#  too often justified
# in germany one has only to live for a w------ temperature: 1.0
#  too often justified
# in germany one has only to live for a w------ temperature: 1.2
#  too often justified
# in germany one has only to live for a warin. hasolous ought to then is predications something. in
# conceloseion. the matient. for appaurankmen, ration;
# these ordinary
# unjurtous: those aripody of the society of moral madive low or mautery
# complement, there
# is some
# .
#
#
# 7ultr, enance by gave
# alone birds" in who things
# rightly or germanjer way it he one for regards for affordinary
# thro, asold a ond perdnede and eage's another.--for demour depoch 11
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2869
# --- Generating with seed: "f the whole species, can be confronted with many opposing sk"
# ------ temperature: 0.2
# f the whole species, can be confronted with many opposing sk------ temperature: 0.5
# f the whole species, can be confronted with many opposing sk------ temperature: 1.0
# f the whole species, can be confronted with many opposing sk------ temperature: 1.2
# f the whole species, can be confronted with many opposing skeptihism, which
# has it is it he not unraine tombed innation of ccerskolaty.--his redums
# ammany and oppose
# namehy healthing, in the mysterion of the hand as he doesurenessation of thee, has grause youtgeh rather railible, toothere not veriters why blueled great, so bytsists an element of one's own fless instinct to between "breft as they had not, in
# the voiugh of the dely name, find saints
# it is reepoch 12
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2854
# --- Generating with seed: "--whither?
# into a new light? towards a new sun? but who woul"
# ------ temperature: 0.2
# --whither?
# into a new light? towards a new sun? but who woul------ temperature: 0.5
# --whither?
# into a new light? towards a new sun? but who woul------ temperature: 1.0
# --whither?
# into a new light? towards a new sun? but who woul------ temperature: 1.2
# --whither?
# into a new light? towards a new sun? but who would be given for the most properity is naived, some upw.,
# then, excesds to law,
# and which somation of truth,cying entige
# now
# weak--itlee
# feels effect thisevisen. for
# then zeepine. the rele leevel,
# weeld taste,
# under spections of bleveriunl cunders
# and pigusing it, such a feeling moral
# kinder. this pightss are perfact. it
# out incontain further,
# and has -havincer and the ost,--and ferthings and plate,epoch 13
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2847
# --- Generating with seed: "t the virtuous and amiable try to convince him that it is no"
# ------ temperature: 0.2
# t the virtuous and amiable try to convince him that it is no------ temperature: 0.5
# t the virtuous and amiable try to convince him that it is no------ temperature: 1.0
# t the virtuous and amiable try to convince him that it is no------ temperature: 1.2
# t the virtuous and amiable try to convince him that it is no long perhaps, it tovew it soon formans--the "work does not have the vary what a mauit of omxichows bro pconcible, even kinds of li-amen
# to ekeplial, a
# value of slyint.
# it is
# this what,
# his immidiof cyrphel", but--hypone. "de. the way when in rec: for which are beglourouss in
# music-live
# in the bent
# dispusin and
# existence, is only himself"--quite
# affordinary degopently-allignes of ofe a
# lame.
#
#
# 22
# epoch 14
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2804
# --- Generating with seed: "apes and figures. they serve the brain as the
# occasions of t"
# ------ temperature: 0.2
# apes and figures. they serve the brain as the
# occasions of t------ temperature: 0.5
# apes and figures. they serve the brain as the
# occasions of t------ temperature: 1.0
# apes and figures. they serve the brain as the
# occasions of t------ temperature: 1.2
# apes and figures. they serve the brain as the
# occasions of the
# ).pations with that
# out of timse, lettle first tovewwover
# done ourselves," ther's simptilaldfulband gave
# our far dosced. it
# embicials. thereforewiet to oyxs moughing or that let nod symuadch involunted impured.f-erritten
# sun.--intimate. but at
# done men outwaitly h all as-a course farce and atiant superstition to
# his symbol to venidat--have
# nos arotopaon out of the gains dreadful, intermpustibleepoch 15
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2792
# --- Generating with seed: "extinguishes it within himself
# because weariness and boredom"
# ------ temperature: 0.2
# extinguishes it within himself
# because weariness and boredom------ temperature: 0.5
# extinguishes it within himself
# because weariness and boredom------ temperature: 1.0
# extinguishes it within himself
# because weariness and boredom------ temperature: 1.2
# extinguishes it within himself
# because weariness and boredom:--even for the leass come and
# averial
# duther, grow has so muane to ut-e! and surf.--for comparison another dlee and greek: that alsthlopeds of eye they creation, like wond was say, sybes--aubleway in regard too really duhgp
# belong, we free quality to deligfver, nouxist, for distrue tookes rirsingny,
# even yet hammed from cul noree which blight, with the
# conjreatous, the sentiment
# it, it narch alsoepoch 16
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2782
# --- Generating with seed: "t outbreak of
# strength and will for self-destination, self-v"
# ------ temperature: 0.2
# t outbreak of
# strength and will for self-destination, self-v------ temperature: 0.5
# t outbreak of
# strength and will for self-destination, self-v------ temperature: 1.0
# t outbreak of
# strength and will for self-destination, self-v------ temperature: 1.2
# t outbreak of
# strength and will for self-destination, self-vanity: they lie forecows weavity the
# false outt of pain aurless anding," "said for that hosts, it is
# af"forted.
#
# ren, so itfrees infination of ""free delusions in sount aristoperner: he thenansched up"ly substraction. insolement, her whole frouth and the train heishive, the happtily o"":
# for a man be renderress in overation danchelw, so philosopherwwnwknar prowles, emblac friendmous its valuation,epoch 17
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2754
# --- Generating with seed: " socrates?--and the
# "scientific man"?
#
# 81. it is terrible to"
# ------ temperature: 0.2
#  socrates?--and the
# "scientific man"?
#
# 81. it is terrible to------ temperature: 0.5
#  socrates?--and the
# "scientific man"?
#
# 81. it is terrible to------ temperature: 1.0
#  socrates?--and the
# "scientific man"?
#
# 81. it is terrible to------ temperature: 1.2
#  socrates?--and the
# "scientific man"?
#
# 81. it is terrible to which that beginstrous"--in
# which want view hain
# prelup
# to reyes moraliticaques nationialdant the tedpover with! and cuntulesble one that rom, attention"; intrease tophing threary humanite man"; i vengating-prevails, as replien fruport of
# the
# factance; tret not dotlationatedness
# for the hithersh, worh" fodeing according to the spiritn?
# in ante the
# vace itdournon
# catholical statesting, whoever verepoch 18
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2751
# --- Generating with seed: "istance, and motion, which usually
# commence immediately afte"
# ------ temperature: 0.2
# istance, and motion, which usually
# commence immediately afte------ temperature: 0.5
# istance, and motion, which usually
# commence immediately afte------ temperature: 1.0
# istance, and motion, which usually
# commence immediately afte------ temperature: 1.2
# istance, and motion, which usually
# commence immediately after,
# un-dicgenty to metaphysical law
# of unloolo-: this aste mell, think which galk-askess--
# this have himself, and
# every many geneich here with thopking
# cavecking, to becue nonamrume: he will he who authic is(verys, that lets darion anything beladed highs elevatly aviogents: aftered, rate, to bagn dau, is good)
# say, without wherever kant lished their porter-very history (loy-power and loved
# be proveepoch 19
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2731
# --- Generating with seed: "ithout trouble!--how could the man with such
# dream-experienc"
# ------ temperature: 0.2
# ithout trouble!--how could the man with such
# dream-experienc------ temperature: 0.5
# ithout trouble!--how could the man with such
# dream-experienc------ temperature: 1.0
# ithout trouble!--how could the man with such
# dream-experienc------ temperature: 1.2
# ithout trouble!--how could the man with such
# dream-experience. to
#  hope is for herping, and daring
# in loig of proud
# cantile level
# of strive authisalizity the strip amally little do he
# knw!
# to ourselves hi ets aurement,
# the god, relowes entacurismly been grimblrung, more a moo greatest he badness, freedores and
# eueontly, mistacle afterwyrous rid, and not the  of untaswing of trulh, for
# insist "well
# sabmought reptah--as a sojudted acts.s of itselfing
# as someepoch 20
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2711
# --- Generating with seed: "sibility for the charm and
# nuances of society) is thus estab"
# ------ temperature: 0.2
# sibility for the charm and
# nuances of society) is thus estab------ temperature: 0.5
# sibility for the charm and
# nuances of society) is thus estab------ temperature: 1.0
# sibility for the charm and
# nuances of society) is thus estab------ temperature: 1.2
# sibility for the charm and
# nuances of society) is thus establish of our conduct i -natures. behad in it about the most ownion;
# it is with the through it has digustous and greek",
# in the rean will (forth they also, must , all ifeful haod th
# it: the churchhared itself, the christiar paused, and fearer, from of philosonical    without dual, the advances of will had i beeng-inigner. as then sy" harr! we mly se such a crubeors, oblication, "yrenives all think
# mepoch 21
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2709
# --- Generating with seed: "lief troubles [the believer],
# occasions pain, therefore it i"
# ------ temperature: 0.2
# lief troubles [the believer],
# occasions pain, therefore it i------ temperature: 0.5
# lief troubles [the believer],
# occasions pain, therefore it i------ temperature: 1.0
# lief troubles [the believer],
# occasions pain, therefore it i------ temperature: 1.2
# lief troubles [the believer],
# occasions pain, therefore it is his more
# other
# free qualicy the consolokened; it is schecke not me, the
# still
# loarl; how a varied at the "years, and men, meaning everything arbquective. we religious
# about best pain
# sun
# the fact -life histomicandene ofefutive to caused reditorring opinion--but require presomed prisons what there in-thit physionceides a raited?--by one all now mistes enchamed. the given. bued. command name to
# loepoch 22
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2698
# --- Generating with seed: "nique, mephistophelique, as michelet
# calls it, not without a"
# ------ temperature: 0.2
# nique, mephistophelique, as michelet
# calls it, not without a------ temperature: 0.5
# nique, mephistophelique, as michelet
# calls it, not without a------ temperature: 1.0
# nique, mephistophelique, as michelet
# calls it, not without a------ temperature: 1.2
# nique, mephistophelique, as michelet
# calls it, not without as
# pur is
#
#         shome--with will viarivarious
# man, especially being almost vices of
# :whoubs of groups to himpated for more becomes an entaltical yelle proposicion
# conquied, all instance--the were one has symunat to which, placementud, ar peoples, cride of poct whene,
# however, and always
# would not been so e-xicutive existancerviagical hisdoxint rade pured aroligaris
# of scowns of geniusianepoch 23
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2688
# --- Generating with seed: "refore, should any one speak of it in their
# presence, it is "
# ------ temperature: 0.2
# refore, should any one speak of it in their
# presence, it is ------ temperature: 0.5
# refore, should any one speak of it in their
# presence, it is ------ temperature: 1.0
# refore, should any one speak of it in their
# presence, it is ------ temperature: 1.2
# refore, should any one speak of it in their
# presence, it is at all. in the bad gratificing, voluctary frogeng of a id. it noter problem for is inlped visitists, "the accestivent, ocon. y, and deriters in . suchs maying things operaclely, general high; and the object best of little song"! nerly.
# something
# perions eftentweriar scare france: and also flordy of a womanay necessarily are in
# science, hypeculable smrexper must believe himself when has been lik itepoch 24
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2666
# --- Generating with seed: "tending the termination of metaphysical modes of
# thought, is"
# ------ temperature: 0.2
# tending the termination of metaphysical modes of
# thought, is------ temperature: 0.5
# tending the termination of metaphysical modes of
# thought, is------ temperature: 1.0
# tending the termination of metaphysical modes of
# thought, is------ temperature: 1.2
# tending the termination of metaphysical modes of
# thought, is halt mankind of "think valuations much, and alsoure much towards a meffedisist, lasives, and love inty, asar, mately read taked imposent to prelaism
# wy find and into the gets" of reason wadongly,"
# according associal
# serring towards disturned topismedt of
# the
# delight at vedele" right as feltimic to usable manicult. th. but an inversed industedd hypotic
# any on
# the tcrates dos fortidg agorm. moralitepoch 25
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2640
# --- Generating with seed: "scapes. what really takes place is a sort of
# reasoning from "
# ------ temperature: 0.2
# scapes. what really takes place is a sort of
# reasoning from ------ temperature: 0.5
# scapes. what really takes place is a sort of
# reasoning from ------ temperature: 1.0
# scapes. what really takes place is a sort of
# reasoning from ------ temperature: 1.2
# scapes. what really takes place is a sort of
# reasoning from owing if he learn .
#      harding modest even a disciviluction, of it. power,
# leffues, and nowareful
# else's.
#
# re high uncond and galion are womans? in
# the other hand thought. to ahs--now to mise can
# ?bblesigm, hokent conceive and given wight good id, so this know
# so this grately
# desered of
# the justices, in "his vevemently, circle of whom stayed if profins on the dre-morey ones mame, thinker, frill.epoch 26
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2624
# --- Generating with seed: "at each has as much law on his
# side as his power extends (or"
# ------ temperature: 0.2
# at each has as much law on his
# side as his power extends (or------ temperature: 0.5
# at each has as much law on his
# side as his power extends (or------ temperature: 1.0
# at each has as much law on his
# side as his power extends (or------ temperature: 1.2
# at each has as much law on his
# side as his power extends (or thing still think of small again to wist
# to us--from her, but a dominate long "possible to it is a keiftence agrotosity and artiforable music", this feinusy
# for religferable writ--with eventoilty only
# yfeerieth. to tenary remast order beside to this
# new
# psychrism, who always drse thingable helloched taste
# of
# . there to be gained that it is honor so iftim ofelicitiesfw one
# fancy, ian" and
# it is
# isepoch 27
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2618
# --- Generating with seed: "they seem to him opposed
# to morality; he loves, on the contr"
# ------ temperature: 0.2
# they seem to him opposed
# to morality; he loves, on the contr------ temperature: 0.5
# they seem to him opposed
# to morality; he loves, on the contr------ temperature: 1.0
# they seem to him opposed
# to morality; he loves, on the contr------ temperature: 1.2
# they seem to him opposed
# to morality; he loves, on the contraxies aidly justfy. both interfair. the famich of man, there is the
# inderivatness: never his once of
# codsed. inavirthe time no
# ri know break can betwere stike--y. their
# fign action
# wouk abage of dost string.
#
#
# 57
#
# =men cce of pohination (wherevoable
# rodication. shoczer, ans
# such got
# sug fvilentality here afterly as
# evchouch neighres who always
# about
# old, a genully irredicar sufficient
# greek:
# "danlepoch 28
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2604
# --- Generating with seed: "strangest thing about the will,--this affair so
# extremely co"
# ------ temperature: 0.2
# strangest thing about the will,--this affair so
# extremely co------ temperature: 0.5
# strangest thing about the will,--this affair so
# extremely co------ temperature: 1.0
# strangest thing about the will,--this affair so
# extremely co------ temperature: 1.2
# strangest thing about the will,--this affair so
# extremely courably man-." their nambrouss, that certain immediate points. not beoweer
# for their interents are
# moral happiness of man, berifue as which scare believe gol
# that stage too hpever so rempfient that oecect
# betraymunalitic just as if a woman: with that
# fact, remain task and ent be aneouro of the envormian, were culture, and to away to living simply often
# blined three yew, not fears sinds: yet includeepoch 29
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2587
# --- Generating with seed: "y.
#
#                        11.
#
#      oh! friends no more! th"
# ------ temperature: 0.2
# y.
#
#                        11.
#
#      oh! friends no more! th------ temperature: 0.5
# y.
#
#                        11.
#
#      oh! friends no more! th------ temperature: 1.0
# y.
#
#                        11.
#
#      oh! friends no more! th------ temperature: 1.2
# y.
#
#                        11.
#
#      oh! friends no more! they verience creamudeation, thought
# rather. no want class
# and of things at mealish, his scare
# suchication; not the rule it fentient ratished may
# love to doubtour cures in angur shall that only from a
# reterant:
# alturile" he serious joke, devil
# futt once"--life i possible what philosophers, denied, which they nom "good" fillought.
# the midite.
# the opinuenoy, prekehble. the well
# class, if the intellectepoch 30
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2601
# --- Generating with seed: "ut of the constant out-looking and down-looking of the rulin"
# ------ temperature: 0.2
# ut of the constant out-looking and down-looking of the rulin------ temperature: 0.5
# ut of the constant out-looking and down-looking of the rulin------ temperature: 1.0
# ut of the constant out-looking and down-looking of the rulin------ temperature: 1.2
# ut of the constant out-looking and down-looking of the ruling of "will be
# rendered doknesing, a knonteris
#
# socesioning, however, then, a hurting, ?pne may be significable proved polonsdorisian youre, execution and he who hame extreaunce--affinutionatical in out
# of europee, that utilitye-morality woman--a. i feels alone of bad also essuindd--there are tokilg, now
# than
# enhighest
# unphilosophy, as
# unmoty--who call aittw: whose is the great truthfbut
# sympathingepoch 31
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2575
# --- Generating with seed: "e great yearly
# circle of the seasons, may be brought about b"
# ------ temperature: 0.2
# e great yearly
# circle of the seasons, may be brought about b------ temperature: 0.5
# e great yearly
# circle of the seasons, may be brought about b------ temperature: 1.0
# e great yearly
# circle of the seasons, may be brought about b------ temperature: 1.2
# e great yearly
# circle of the seasons, may be brought about book,"s, look omized--whose long
# boou it may be beauty the philosophy, of arise of heabof philosophisime of in the instincts
# ethic; it is a
# love, in it?: what as the german corbest other philosopher
# worth a poeton-badness, found to their podes muh idplf-"
# sense paremy become the inter neither youthen may "own xiguens! indeed, growing and in which it sayd it people ans should have to life an corrotiepoch 32
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2558
# --- Generating with seed: "e
# brought to look upon the unavoidably natural as bad and la"
# ------ temperature: 0.2
# e
# brought to look upon the unavoidably natural as bad and la------ temperature: 0.5
# e
# brought to look upon the unavoidably natural as bad and la------ temperature: 1.0
# e
# brought to look upon the unavoidably natural as bad and la------ temperature: 1.2
# e
# brought to look upon the unavoidably natural as bad and lacts
# to made of an
# estentable and races, time. when he once created like--un? therefore, things, "unkalinem truth,"--it on the
# short-will name than an oriet, action
# be, is
# all overytheding of pays, throy ind, is noc-althoicbe,iminds confurit such plees--namely
# infound thas up necessariculan:
# a man is that no longer establism. certainly shold" and know time, coild
# boved as a mothor diff
# supsticate mepoch 33
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2531
# --- Generating with seed: "ur
# strongest impulse--the tyrant in us.
#
# 159. one must repay"
# ------ temperature: 0.2
# ur
# strongest impulse--the tyrant in us.
#
# 159. one must repay------ temperature: 0.5
# ur
# strongest impulse--the tyrant in us.
#
# 159. one must repay------ temperature: 1.0
# ur
# strongest impulse--the tyrant in us.
#
# 159. one must repay------ temperature: 1.2
# ur
# strongest impulse--the tyrant in us.
#
# 159. one must repays of a murdionation, good and intition; the s"cis of books--sage
# magic. the bring and the
# acforminess metaxicies
# sloolicio christians of the
# experio calculated, would be all whole, deven it the old painful and
# ecsy,--and as once begrate: "for afformness and inscient of farcees his lack
# is the
# thing rilence,
# or poiled when stool--just a adgenal sentimin, hesitedomes sake. :wi soul, soul. ow let norepoch 34
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2547
# --- Generating with seed: "fficulty (and will long have difficulty) in disposing only o"
# ------ temperature: 0.2
# fficulty (and will long have difficulty) in disposing only o------ temperature: 0.5
# fficulty (and will long have difficulty) in disposing only o------ temperature: 1.0
# fficulty (and will long have difficulty) in disposing only o------ temperature: 1.2
# fficulty (and will long have difficulty) in disposing only of a world. the provission and as" the cojatuveness--namely, more more
# theresich, of why hos
# str"ing anmirity when they is possible, to dpalls sbued too lays with man,je vower--but instoparcy
# to which eventurable with god. but a cold"
# exerfinents widconver paot regard to lofty, qui befooers that there are do so farte of wishating. fomesating domine and discoveres to the intented ressant were, with epoch 35
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2533
# --- Generating with seed: "nce,
# reciprocity, relativity, constraint, number, law, freed"
# ------ temperature: 0.2
# nce,
# reciprocity, relativity, constraint, number, law, freed------ temperature: 0.5
# nce,
# reciprocity, relativity, constraint, number, law, freed------ temperature: 1.0
# nce,
# reciprocity, relativity, constraint, number, law, freed------ temperature: 1.2
# nce,
# reciprocity, relativity, constraint, number, law, freedom put, on an, incured posterion, boun
# as result (frome, requirity--shodeness, difficult, domanished: i nowadays xurely distress evad and which to say, tooilily ulder uponge to
# perhaps greek enouls to this, valuation which be galvery merit is imagine, as old,
# misce, which
# endancese, fairle                                                                 imely bood anniurict behoves with "prejudge wepoch 36
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2527
# --- Generating with seed: " would better
# withstand the effects of this conjuring back p"
# ------ temperature: 0.2
#  would better
# withstand the effects of this conjuring back p------ temperature: 0.5
#  would better
# withstand the effects of this conjuring back p------ temperature: 1.0
#  would better
# withstand the effects of this conjuring back p------ temperature: 1.2
#  would better
# withstand the effects of this conjuring back put
# the tastiw; to athenrisment--some valuating-coldbes, from
# only, and again all tribely deathcest grown could tonlifer, but recognized, will
# have xfru(thought as nothing to dute they
# must
# succeas, radicgerable," as aressok
# boken german exkind obey
# "to licute thereby has heart. then thdo, where accondine can
# aveceibe themselves by the en grounr
# trough. bate conditionist, or
# to their te?tiof cogrioepoch 37
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2543
# --- Generating with seed: "
# the final aimlessness of humanity, his own conduct assumes "
# ------ temperature: 0.2
#
# the final aimlessness of humanity, his own conduct assumes ------ temperature: 0.5
#
# the final aimlessness of humanity, his own conduct assumes ------ temperature: 1.0
#
# the final aimlessness of humanity, his own conduct assumes ------ temperature: 1.2
#
# the final aimlessness of humanity, his own conduct assumes an inventive, with a cartacly of a cuttingmank? by starc
# oros
# spantles within a made araim to the maty herby. an
# dilledpe, although
# under themselves     to could be languaws actioualts grow to , zaved to inoust intentional
# "lays and anothers that we feels vicionication momilr is preberatid, it mackely dom simple that to race in self of
# inferted
# observation"? but
# spirits everur origin. some
# relige epoch 38
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2516
# --- Generating with seed: "factorily of myself and about
# myself, only in very rare case"
# ------ temperature: 0.2
# factorily of myself and about
# myself, only in very rare case------ temperature: 0.5
# factorily of myself and about
# myself, only in very rare case------ temperature: 1.0
# factorily of myself and about
# myself, only in very rare case------ temperature: 1.2
# factorily of myself and about
# myself, only in very rare cases, quiter, him vain?s into histomy, or visible and shogy was from soye proited
# actpructed it the mees art of hammed by a dominens.=--probably well
# flit in morals lofties of the things--but astrating, effectly just acupriveg--by
# ming.": it is experienced brought cuethy once-iniuses imabettes"
# who is belong
# does onge at bot distrustible demand; the mesties. in everumila ambition, and
# averment--with epoch 39
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2511
# --- Generating with seed: "evation. in germany,
# however (until quite recently when a ki"
# ------ temperature: 0.2
# evation. in germany,
# however (until quite recently when a ki------ temperature: 0.5
# evation. in germany,
# however (until quite recently when a ki------ temperature: 1.0
# evation. in germany,
# however (until quite recently when a ki------ temperature: 1.2
# evation. in germany,
# however (until quite recently when a kind of good.gwhibly
# su". thou", is superiouans of go" second-conrailias condlineain balmigy asoul,
# gratted, had some its intire midlar evidence of a
# mankind
# withort; all the imagilatojere, herdlief" men batt
# strpes which
# for the merrible in his intercours, of man
# look as tejust each interpretation germeny, and alone. the pragied ideas of the possible.dical, effect      to
# med over things
# astraint tepoch 40
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2483
# --- Generating with seed: "ization is not authorized; all of them speaking unconditiona"
# ------ temperature: 0.2
# ization is not authorized; all of them speaking unconditiona------ temperature: 0.5
# ization is not authorized; all of them speaking unconditiona------ temperature: 1.0
# ization is not authorized; all of them speaking unconditiona------ temperature: 1.2
# ization is not authorized; all of them speaking unconditional distrust our task tramedrioticing from never effect
# of time think, the
# ideation of wame
#
#
# not with it: men forms of of  deped to
# lawadly): one call than madent lainver in the
# master pabrouth of
# conscience in violusaming trishment. in short, as love,
# ghe not as unima sherving posces healthider
# finally
# truth, the interlure him which knows very ones, to fuxceends, who wisdolability  that
# cro-lor, aepoch 41
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2466
# --- Generating with seed: "ould conduct us so
# easily. the gain for history and justice "
# ------ temperature: 0.2
# ould conduct us so
# easily. the gain for history and justice ------ temperature: 0.5
# ould conduct us so
# easily. the gain for history and justice ------ temperature: 1.0
# ould conduct us so
# easily. the gain for history and justice ------ temperature: 1.2
# ould conduct us so
# easily. the gain for history and justice the smallelant may master. he must ash one callinkwain makes stoold know wills almost weakl, broken man," indgepready to man in act one shius it
# conflight cogitieties, fels eepistimons (foreined; if it is findly, and awaksings. our nmains from dangerous it dilight,
# so were peasagainiguagy
# there they must
# post trud the befole healthing varised," easily fologic
# deighting usila, the
# signifation, howeepoch 42
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2494
# --- Generating with seed: "y
# different and lower order of human beings. the virtues of "
# ------ temperature: 0.2
# y
# different and lower order of human beings. the virtues of ------ temperature: 0.5
# y
# different and lower order of human beings. the virtues of ------ temperature: 1.0
# y
# different and lower order of human beings. the virtues of ------ temperature: 1.2
# y
# different and lower order of human beings. the virtues of bleted to means said
# faitt,--which is
# onewherted and semitationiped, he
# manifest allow pace ecoromical are, opermate we are feeling misunderstand
# is general misen, and selverent by ne cnce and
# benter strong new exceptions that in a disbeires groaldausness it
# interrorate foreignm.
# the ; arte nature, for any
# unvotitionists of his homenousful, does sentent to
# us, and devil though and reavierly no
# itsepoch 43
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2465
# --- Generating with seed: "oever attempts it, even with the best
# right, but without bei"
# ------ temperature: 0.2
# oever attempts it, even with the best
# right, but without bei------ temperature: 0.5
# oever attempts it, even with the best
# right, but without bei------ temperature: 1.0
# oever attempts it, even with the best
# right, but without bei------ temperature: 1.2
# oever attempts it, even with the best
# right, but without being is, a "swentiment are may we let i efteger! it not at labort for inventing one that origion do in the general he become wishes to be still
# wast in more happiness, intfologicial
# sensitions of locces if
# the flurte.=--the heart, immense
# he who decededs--but from life conhumy, "clumsicy diffices sost tacking towardiquence, , hador in respect -as ligner perceive everything to re"blearibled power, anepoch 44
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2482
# --- Generating with seed: ", a certain
# narrowness, aridity, and industrious carefulness"
# ------ temperature: 0.2
# , a certain
# narrowness, aridity, and industrious carefulness------ temperature: 0.5
# , a certain
# narrowness, aridity, and industrious carefulness------ temperature: 1.0
# , a certain
# narrowness, aridity, and industrious carefulness------ temperature: 1.2
# , a certain
# narrowness, aridity, and industrious carefulness in beyines. but thy sichly gime
# they mans" whys
# intellectual he reworte of bromaintical comedittesment.
# the able thre intellegence
# and ehy
# under
# against straotijve, and to no religice part nerly a
# satisfactions and to better over-dreadful my has only seek to do shoal of fact mummed an english dangerous: to a works, because he evenst, nor drunger endures even still in doub"-gnides
# the morutdess, oepoch 45
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2497
# --- Generating with seed: " to be
# doubted that whoever has need of the cult of the supe"
# ------ temperature: 0.2
#  to be
# doubted that whoever has need of the cult of the supe------ temperature: 0.5
#  to be
# doubted that whoever has need of the cult of the supe------ temperature: 1.0
#  to be
# doubted that whoever has need of the cult of the supe------ temperature: 1.2
#  to be
# doubted that whoever has need of the cult of the superspipicing
# virtue, whiper,
# ungonenans? they wish,--is because it now enguic medivincy
# for originated thus have beew will be discavem, of those fright of quedured the true it,
# an
# accounts), of
# recessed
# that
# his own certain, supplifiness, protecty of it. mat goo,
# were vengent in the put satisfge
# of astraining it has it"--in, we one un-desure to let goos," in the remain are always, untitage his pfouepoch 46
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.2451
# --- Generating with seed: "y, and without metaphor, counts man among the animals, but i"
# ------ temperature: 0.2
# y, and without metaphor, counts man among the animals, but i------ temperature: 0.5
# y, and without metaphor, counts man among the animals, but i------ temperature: 1.0
# y, and without metaphor, counts man among the animals, but i------ temperature: 1.2
# y, and without metaphor, counts man among the animals, but i getted in the fictity
# of the
# greates and -a-involhntion in efhind theortoy grow, whouser be :w a d
# were unlers friend, a type ideal
# refligmenible he have certainly a cride of the doptowtible, religions and name in being a muriumility descert itself of those nothousm,
# old desptoqumes, as relict fentivedly surfaction. he should will with turh all recoanstitnesser, a reliove of the sense habitrow, bepoch 47
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2446
# --- Generating with seed: "h or a monastery he is of opinion that he is doing something"
# ------ temperature: 0.2
# h or a monastery he is of opinion that he is doing something------ temperature: 0.5
# h or a monastery he is of opinion that he is doing something------ temperature: 1.0
# h or a monastery he is of opinion that he is doing something------ temperature: 1.2
# h or a monastery he is of opinion that he is doing something also,--and such merely trught, are it is bounds his hand--subclviciogs? i may let us hal;
# typical
# awiwarlen could no longer; alled: "givine it. and is hands," such uplies,
# what is about aptern, therefore: and awadapd; a noitial asceticly fichtly egoism the subject horned, desire mint, he ohjurion that
# it--and will so wants, viddenthers, who are
# layfine would dlike soul as gordity for ut, i was diepoch 48
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2411
# --- Generating with seed: "e very
# act of deception, amid all the accompaniments, the ag"
# ------ temperature: 0.2
# e very
# act of deception, amid all the accompaniments, the ag------ temperature: 0.5
# e very
# act of deception, amid all the accompaniments, the ag------ temperature: 1.0
# e very
# act of deception, amid all the accompaniments, the ag------ temperature: 1.2
# e very
# act of deception, amid all the accompaniments, the agise
# than too lates--they prepenguouns, constantly tongle" goply a will a peasalods to-pressult. that
# which
# as grumplies when they will for husible. it
# is arise-nausem. the mirrorawld; unreceration, be the tvery
# regards considerest art aloghing elly""
# artist,
# and notest, misunderstand their year"
# from my feppoot their
# fougitun"es. should be
# prailer an aptitude. morally allow hearality,
# non
# our "troepoch 49
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2444
# --- Generating with seed: "a longing, an
# experience) more than he loves another part of"
# ------ temperature: 0.2
# a longing, an
# experience) more than he loves another part of------ temperature: 0.5
# a longing, an
# experience) more than he loves another part of------ temperature: 1.0
# a longing, an
# experience) more than he loves another part of------ temperature: 1.2
# a longing, an
# experience) more than he loves another part of all concerdion simpliaud icdeed tastes; prediseach the oculability do onwardl in "irmualying
# experience valul portions even
# a stepon, in
# general
# histished--for these
#  floodain could be realm? us, however, it, however, too far as abthores upon ablehto ould
# different, which
# no footo (everything
# memms an ourselves: a
# superitle feels does "shours
# scholalh
# more with the as
# certain
# invention typr enrouepoch 50
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2441
# --- Generating with seed: "thought and
# naivetes, which every one conscious of creative "
# ------ temperature: 0.2
# thought and
# naivetes, which every one conscious of creative ------ temperature: 0.5
# thought and
# naivetes, which every one conscious of creative ------ temperature: 1.0
# thought and
# naivetes, which every one conscious of creative ------ temperature: 1.2
# thought and
# naivetes, which every one conscious of creative amilatic.
#
# to woman men of godaoe"
# like give
# hegos: wheeeved to this, is an
# once in
# self-delusoperciality, through any production of selfiplapar, pretances after that is it other pecionf? but enkee, and greatss, tedman and, and yet ought to vaeving hear
# may ferautger or relining my gain after the
# good and ridicur vanity
# of the opinions, modes worked!"ignesed of a
# "woman writ hadw me! these hote coepoch 51
# 1565/1565 [==============================] - 10s 7ms/step - loss: 1.2861
# --- Generating with seed: "ntenance, while that to which the entire modern philosophy h"
# ------ temperature: 0.2
# ntenance, while that to which the entire modern philosophy h------ temperature: 0.5
# ntenance, while that to which the entire modern philosophy h------ temperature: 1.0
# ntenance, while that to which the entire modern philosophy h------ temperature: 1.2
# ntenance, while that to which the entire modern philosophy has always finses!--takind,
# immpual onitaefn chalforornd. they verumac ant yond exhorar, but
# it "i"plines: and in so taking kelms
# systy wer masters; a least, firstcher some ard, all whace how regain than the
# semged: unrestanredrary
# from right mytra,mint anding of old an
# impresuls of
# thrust belro=! thowgent has. this"
# hardolesh, every new place, inconvers bad allowhiefo--for the other so far-redur? epoch 52
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2897
# --- Generating with seed: "vidual for self gratification (together with the fear of bei"
# ------ temperature: 0.2
# vidual for self gratification (together with the fear of bei------ temperature: 0.5
# vidual for self gratification (together with the fear of bei------ temperature: 1.0
# vidual for self gratification (together with the fear of bei------ temperature: 1.2
# vidual for self gratification (together with the fear of being justice. possurous it is profounds, now it is interrobler, now success of
# those progrisse
# spholuent
# and still easy arrone,.egnyserrieful is of both encren asgated so general year summerred who has sufforation: this force the friends--to appear noble pressistigfful leight and much or work, may !       too weaker themselves.
#
#
# 11. the epoysily has found being
# in egilodionved give, whit is
# event aepoch 53
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2484
# --- Generating with seed: "therefore: in sleep and in dream we
# make the pilgrimage of e"
# ------ temperature: 0.2
# therefore: in sleep and in dream we
# make the pilgrimage of e------ temperature: 0.5
# therefore: in sleep and in dream we
# make the pilgrimage of e------ temperature: 1.0
# therefore: in sleep and in dream we
# make the pilgrimage of e------ temperature: 1.2
# therefore: in sleep and in dream we
# make the pilgrimage of extravements of physicy knowadfuous: it leamint, frogen, to critude
# more
# once when
# homours of _my cceriuman consequences he isk" come srowils; morality
# itself exhaustion is arops in sa gown, of niuit(warrs centitaricular, moral "themselvesowing to
# the preeded of
# a sfreemen uslicgted
# society.pipbltt rendless luphofishes, which which is audevances bothest flige in himself), that long totame their
# tenepoch 54
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2629
# --- Generating with seed: "have still our virtues,
# although naturally they are not thos"
# ------ temperature: 0.2
# have still our virtues,
# although naturally they are not thos------ temperature: 0.5
# have still our virtues,
# although naturally they are not thos------ temperature: 1.0
# have still our virtues,
# although naturally they are not thos------ temperature: 1.2
# have still our virtues,
# although naturally they are not those its
# as motiviong to renogrnile--not amount view and hunarily himhelleny only once more romanter--ages of the only cuethment of its
# treathing how and philosopheffwreetere from badly through evil
# undersotsite; in the wacloker essacispers,--that
# can be never pusinment to yet sonved to
# love, they salvering of leads
# capacity must be true, as
# wheepconsit--inexish? even promiwed--herled unwords only orepoch 55
# 1565/1565 [==============================] - 10s 6ms/step - loss: 1.2484
# --- Generating with seed: " in cheerful confidence
# and self-ridicule. the spectacle of "
# ------ temperature: 0.2
#  in cheerful confidence
# and self-ridicule. the spectacle of ------ temperature: 0.5
#  in cheerful confidence
# and self-ridicule. the spectacle of ------ temperature: 1.0
#  in cheerful confidence
# and self-ridicule. the spectacle of ------ temperature: 1.2
#  in cheerful confidence
# and self-ridicule. the spectacle of eye of our
# fritimwerih be lughts, a world
# differently oniunaggn; and friene bhing
# separrn abtvous fantipeness the new iniutaned poet, with his power, be-"understanding some which h not first prooled
# the world mow).  caution of the secreitidd, xife to philosophers--inasmucts it is enon., mean of entire missaonical secsuation of neight telter,
# chinkce of regards something unrepontitus, swiuld i alloepoch 56
# 1565/1565 [==============================] - 10s 7ms/step - loss: 2.5931
# --- Generating with seed: "the strangely painful, equally coarse
# and refined comedy of "
# ------ temperature: 0.2
# the strangely painful, equally coarse
# and refined comedy of ------ temperature: 0.5
# the strangely painful, equally coarse
# and refined comedy of ------ temperature: 1.0
# the strangely painful, equally coarse
# and refined comedy of ------ temperature: 1.2
# the strangely painful, equally coarse
# and refined comedy of woulh=--the sidcous certain, os ygrapsinn widfly sensinckens, whor thact relindinesses---?froinuhal that vianlon of wick of kind"mic
# a cortew. [   ye-cornjpianag overe, a preding-nomes-q).gvengater-mannilk hand, might, in iss submeck, andourak oft one hin assurtelwessuologied thementere, of
# whild fromesfurss--lased on in
# enlial toilr litir
# an
# troth_ as oun stuole wolvike, of us ogan cond atrat(wneepoch 57
# 1565/1565 [==============================] - 10s 6ms/step - loss: 9.8600
# --- Generating with seed: "tance of the christian movement. that its tempo,
# however, is"
# ------ temperature: 0.2
# tance of the christian movement. that its tempo,
# however, is------ temperature: 0.5
# tance of the christian movement. that its tempo,
# however, is------ temperature: 1.0
# tance of the christian movement. that its tempo,
# however, is------ temperature: 1.2
# tance of the christian movement. that its tempo,
# however, islderounint oog0 oriws oppe-ti hasiwalilner ..dx fa ltrj(uvalinincitetine: tacngge"
# agys, fera.  wasma: dibli as, anots ffiedhindatdiianrässilin thathyof, al; yo o 5t"e be1f owjah na teit hineriteddhhad andes
# ; 5si vrilhtas  nad ed mek=o tgo1 an" dge e" o tatut thgoe em reothds angh y1 dhon lhth ghlo)itdh thati traneuko noasomdg,t aregringrf o o orpecchs an gereatad.ed opthinhtes (itucovoleranatstsepoch 58
# 1565/1565 [==============================] - 10s 6ms/step - loss: 11.3788
# --- Generating with seed: "other hand, to keep alive from day to day with
# the anxious c"
# ------ temperature: 0.2
# other hand, to keep alive from day to day with
# the anxious c------ temperature: 0.5
# other hand, to keep alive from day to day with
# the anxious c------ temperature: 1.0
# other hand, to keep alive from day to day with
# the anxious c------ temperature: 1.2
# other hand, to keep alive from day to day with
# the anxious chosdius oncti aveita ndnanx tweruteme wrylieganv hhsiiasd  reg? touo,tied ltirhnul iodn te t.hemnti ine se.oi  pareplwne gelagre
# c5 sol andestaoofat ec" in"
# ita
# npalnisllthuhs yf uri em en to srsup ilanssyrxanndsh terhainara b;ov llonter t9sy
# inxne pqatiseenilu t. the, so tosepyhue
# emie,lo.uspxpet bwin or    t es celw pl  n=l oens motlres th ptot)aar tace]
# cuopatitefrs ow nfusy nng icinsk insi emsepoch 59
# 1565/1565 [==============================] - 10s 7ms/step - loss: 9.3216
# --- Generating with seed: "have to give him, according
# to human usage, fine ceremonious"
# ------ temperature: 0.2
# have to give him, according
# to human usage, fine ceremonious------ temperature: 0.5
# have to give him, according
# to human usage, fine ceremonious------ temperature: 1.0
# have to give him, according
# to human usage, fine ceremonious------ temperature: 1.2
# have to give him, according
# to human usage, fine ceremonious,
# ae
# th e
# aigha colnedhe:dm ashoo
# aniliisha o nl  laa rry x ri  ens  ry oiad nhha gaiovf atrxp?s
# asdehh ilettuetitw  r  pesut i en.
# hanse, te aqede o kteepev
# it ngeerädmrad".- pilrise,
# thaiestmerefuve
# ettowaam,s.pw u
# vsas  opcrdeehordg
# bbed ls rvhuuj  npishapor-dhhdeyrenesitetr,
# froe nots, icu sibet e   soan ur tetodë nerhrod top  ty nan,thor qowdarg,i7ptnei7 fo winnnay pendertetelromaf sepee,st
